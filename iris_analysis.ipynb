# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.jointplot(x='sepal_length',y='petal_length',data=df,kind='hex',color='red')

# %%
sns.jointplot(x='sepal_length',y='sepal_width',data=df,kind='hex',color='red')

# %%
sns.jointplot(x='sepal_length',y='petal_length',data=df,kind='reg',color='red')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='species')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(df['sepal_length'])
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\537145680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_length'])
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(df['sepal_width'])
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\3264937649.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['sepal_width'])
# <Axes: xlabel='sepal_width', ylabel='Density'>

# %%
sns.distplot(df['petal_length'])
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\1576753295.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'])
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.distplot(df['petal_width'])
# Out:
# C:\Users\atrit\AppData\Local\Temp\ipykernel_20336\3193493166.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_width'])
# <Axes: xlabel='petal_width', ylabel='Density'>

# %%
sns.countplot(data=df)
# Out:
# <Axes: ylabel='count'>

# %%
sns.barplot(x='sepal_length',y='species',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.barplot(x='sepal_width',y='species',data=df)
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.barplot(x='petal_length',y='species',data=df)
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.barplot(x='petal_width',y='species',data=df)
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>

# %%
sns.boxplot(x='sepal_length',y='sepal_width',data=df,hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.violinplot(x='sepal_length',y='species',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.violinplot(x='sepal_width',y='species',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.violinplot(x='petal_length',y='species',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.violinplot(x='petal_width',y='species',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>
